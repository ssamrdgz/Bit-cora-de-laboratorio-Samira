# %% [markdown]
# ## Operaciones básicas en Python

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# ### Operación suma

# %%
a = 5
b = 10
print(a + b)
# Out:
# 15

# %% [markdown]
# ### Operación multiplicación

# %%
a = 5
b = 10
print(a * b)
# Out:
# 50

# %% [markdown]
# ### Guardar una variable

# %%
nombre = "Laboratorio"
print(nombre)
# Out:
# Laboratorio

# %% [markdown]
# ### Operación con lista de datos

# %%
datos = [10, 12, 15, 18, 20]

# %%
promedio = sum(datos)/len(datos)

# %%
print(promedio)
# Out:
# 15.0

# %% [markdown]
# ### Operación con datos yo

# %%
datos1 =[5, 17, 31, 4, 53, 42, 62, 10, 95, 20]

# %%
promedio1 = sum(datos1)/len(datos1)

# %%
print(promedio1)
# Out:
# 33.9

# %%
maximo = max(datos1)

# %%
print(maximo)
# Out:
# 95

# %% [markdown]
# ## Funciones en python

# %%
def saludar():
    print("Hola mundo")

# %%
saludar()
# Out:
# Hola mundo

# %%
def sumar(a,b):
    return a + b

# %%
resultado = sumar(7,6)
print(resultado)
# Out:
# 13

# %%
def calcular_promedio(lista):
    return sum(lista) / len(lista)

# %%
lista = [17, 10, 22, 43, 23]

# %%
print(calcular_promedio(lista))
# Out:
# 23.0

# %%
def valor_maximo(c):
    return max(lista)

# %%
print(valor_maximo(lista))
# Out:
# 43

# %%
def valor_minimo(a):
    return min(a)

# %%
print(valor_minimo(lista))
# Out:
# 10

# %%
numeros = [5, 7, 6, 9, 3]

# %%
print(valor_minimo(numeros))
# Out:
# 3
